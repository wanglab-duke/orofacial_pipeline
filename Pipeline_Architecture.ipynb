# %%
import datajoint as dj

from pipeline import lab, experiment, ephys, tracking
# Out:
# Connecting root@10.122.170.76:3306

# %% [markdown]
# ## Subject

# %%
dj.Diagram(lab.Subject) - 1 + 1

# %% [markdown]
# ## Experiment

# %%
dj.Diagram(experiment) - 1

# %% [markdown]
# ## Tracking

# %%
dj.Diagram(tracking) - 1

# %% [markdown]
# ## Ephys

# %%
dj.Diagram(ephys) - 1
