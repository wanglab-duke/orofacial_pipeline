# %% [markdown]
# #### Documentation on insertion: https://docs.datajoint.io/python/manipulation/1-Insert.html

# %% [markdown]
# go one folder up from notebooks folder if needed.

# %%
cd ..
# Out:
# D:\Code\Datajoint\orofacial_pipeline

# %%
from pipeline import tracking
# Out:
# Connecting vincent@datajoint-db.orofacial-sensorimotor-circuits.org:3306

# %%
tracking.Tracking()
# Out:
# *subject_id    *session    *tracking_devi tracking_t
# +------------+ +---------+ +------------+ +--------+
# vIRt47         20          WT_Camera_Vinc =BLOB=
# vIRt49         1           WT_Camera_Vinc =BLOB=
# vIRt49         2           WT_Camera_Vinc =BLOB=
# vIRt49         3           WT_Camera_Vinc =BLOB=
# vIRt49         4           WT_Camera_Vinc =BLOB=
# vIRt49         5           WT_Camera_Vinc =BLOB=
# vIRt49         6           WT_Camera_Vinc =BLOB=
#    ...
#  (Total: 24)

# %%
tracking.WhiskerProcessingParams()
# Out:
# *param_set     set_point     angle_passband angle_stopband phase_passband phase_stopband
# +------------+ +-----------+ +------------+ +------------+ +------------+ +------------+
# whiskers_vince 4.0           4.0            30.0           8.0            30.0
#  (Total: 1)

# %%
# Insert new set of whisker processing params as a dictionary 
tracking.WhiskerProcessingParams.insert1({'param_set': 'whiskers_vincent',
                     'set_point': 4,
                     'angle_passband': 4,
                     'angle_stopband': 30,
                     'phase_passband': 8,
                     'phase_stopband': 30})

# %%
tracking.Tracking.WhiskerTracking()
# Out:
# *subject_id    *session    *tracking_devi *whisker_idx   angle      curvature  face_x     face_y     follicle_x follicle_y tip_x      tip_y
# +------------+ +---------+ +------------+ +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# vIRt47         20          WT_Camera_Vinc 0              =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# vIRt47         20          WT_Camera_Vinc 1              =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# vIRt47         20          WT_Camera_Vinc 2              =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# vIRt49         1           WT_Camera_Vinc 0              =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# ...

# %%
tracking.ProcessedWhisker()
# Out:
# *subject_id    *session    *tracking_devi *whisker_idx   param_set      amplitude  velocity   set_point  angle      angle_raw  angle_bp   frequency  phase
# +------------+ +---------+ +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# vIRt47         20          WT_Camera_Vinc 0              whiskers_vince =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# vIRt47         20          WT_Camera_Vinc 1              whiskers_vince =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# vIRt47         20          WT_Camera_Vinc 2              whiskers_vince =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#  (Total: 3)
