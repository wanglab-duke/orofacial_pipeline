# %% [markdown]
# #### Data ingestion notebook
# The data root directory is specified in the config file (dj_local_conf.json).
#  The commands below will look for data in that directory. Modify it as appropriate.
#  Other information not extracted directly from the data need to be specified there too:
#
# ```     "custom": {
#         "database.prefix": "cosmo_",
#         "data_root_dir": "D:/Data/",
#         "session_loader_class": "VincentLoader",
#         "username": "vincent",
#         "rig": "vincent_ephys_335"
#     }```

# %%
cd ..
# Out:
# V:\Code\DataJoint\orofacial_pipeline

# %%
# import datajoint as dj
# dj.config

# %%
from pipeline.ingest import session_ingest
# Out:
# Connecting vincent@10.122.170.76:3306

# %%
session_ingest.load_all_sessions('vIRt47') #input which subject to load data from 
# if this command fails with `IntegrityError: Cannot add or update a child row`, 
# you need to add that subject first. See `add new subject.ipynb` notebook.
# Out:
# Session {'subject_id': 'vIRt47', 'session_date': datetime.date(2020, 8, 3), 'session_time': datetime.time(18, 14, 23), 'username': 'vincent', 'rig': 'vincent_ephys_335'} already exists. Skipping...

# %%
# check that the import worked
from pipeline import experiment
experiment.Session()
# Out:
# *subject_id    *session    session_date   session_time   username     rig
# +------------+ +---------+ +------------+ +------------+ +----------+ +------------+
# vIRt47         1           2020-08-02     19:52:31       vincent      vincent_ephys_
# vIRt47         2           2020-08-02     20:43:14       vincent      vincent_ephys_
# vIRt47         3           2020-08-02     21:07:00       vincent      vincent_ephys_
# vIRt47         4           2020-08-02     21:16:17       vincent      vincent_ephys_
# vIRt47         5           2020-08-02     21:22:57       vincent      vincent_ephys_
# vIRt47         6           2020-08-03     16:15:03       vincent      vincent_ephys_
# vIRt47         7           2020-08-03     17:08:20       vincent      vincent_ephys_
#    ...
#  (Total: 30)

# %%
# list sessions for one specific subject
experiment.Session & {'subject_id': 'vIRt47'}
# Out:
# *subject_id    *session    session_date   session_time   username     rig
# +------------+ +---------+ +------------+ +------------+ +----------+ +------------+
# vIRt47         1           2020-08-02     19:52:31       vincent      vincent_ephys_
# vIRt47         2           2020-08-02     20:43:14       vincent      vincent_ephys_
# vIRt47         3           2020-08-02     21:07:00       vincent      vincent_ephys_
# vIRt47         4           2020-08-02     21:16:17       vincent      vincent_ephys_
# vIRt47         5           2020-08-02     21:22:57       vincent      vincent_ephys_
# vIRt47         6           2020-08-03     16:15:03       vincent      vincent_ephys_
# vIRt47         7           2020-08-03     17:08:20       vincent      vincent_ephys_
#    ...
#  (Total: 23)

# %%
# list sessions for all except one specific subject
experiment.Session - {'subject_id': 'vIRt43'}
# Out:
# *subject_id    *session    session_date   session_time   username     rig
# +------------+ +---------+ +------------+ +------------+ +----------+ +------------+
# vIRt47         1           2020-08-02     19:52:31       vincent      vincent_ephys_
# vIRt47         2           2020-08-02     20:43:14       vincent      vincent_ephys_
# vIRt47         3           2020-08-02     21:07:00       vincent      vincent_ephys_
# vIRt47         4           2020-08-02     21:16:17       vincent      vincent_ephys_
# vIRt47         5           2020-08-02     21:22:57       vincent      vincent_ephys_
# vIRt47         6           2020-08-03     16:15:03       vincent      vincent_ephys_
# vIRt47         7           2020-08-03     17:08:20       vincent      vincent_ephys_
#    ...
#  (Total: 30)

# %%
# delete sessions for one specific subject
from pipeline.ingest import session_ingest # need to import the ingest script first
(experiment.Session & {'subject_id': 'vIRt43'}).delete()
# Out:
# About to delete:
# `cosmo_ingestion`.`_inserted_session__session_file`: 222 items
# `cosmo_ingestion`.`_inserted_session`: 31 items
# `cosmo_experiment`.`session`: 31 items
# Proceed? [yes, No]: yes
# Committed.
